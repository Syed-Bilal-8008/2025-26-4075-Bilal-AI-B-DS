# %% [markdown]
# <a href="https://colab.research.google.com/github/Syed-Bilal-8008/2025-26-4075-Bilal-AI-B-DS/blob/main/week-6/logisticRegression_spam%20or%20nospam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
url = "https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv"
data = pd.read_csv(url, sep='\t', header=None, names=['label', 'message'])
data['label'] = data['label'].map({'ham': 0, 'spam': 1})
X = CountVectorizer().fit_transform(data['message'])
y = data['label']
model = LogisticRegression()
model.fit(X, y)
msg = ["Free money now!!!"]
pred = model.predict(CountVectorizer().fit(data['message']).transform(msg))
print("Spam" if pred[0] == 1 else "Not Spam")
# Out:
# Not Spam
