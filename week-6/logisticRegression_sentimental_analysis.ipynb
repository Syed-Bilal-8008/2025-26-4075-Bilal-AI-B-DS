# %% [markdown]
# <a href="https://colab.research.google.com/github/Syed-Bilal-8008/2025-26-4075-Bilal-AI-B-DS/blob/main/week-6/logisticRegression_sentimental_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
data = pd.DataFrame({
    'text': ['I love this', 'This is great', 'I hate this', 'This is bad'],
    'label': [1, 1, 0, 0]
})

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data['text'])
y = data['label']
model = LogisticRegression()
model.fit(X, y)
test = ["I love it"]
pred = model.predict(vectorizer.transform(test))
print("Positive" if pred[0] == 1 else "Negative")
# Out:
# Positive
