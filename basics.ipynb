# %% [markdown]
# <a href="https://colab.research.google.com/github/Syed-Bilal-8008/2025-26-4075-Bilal-AI-B-DS/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
# SET OPERATIONS
s1 = {10, 20, 30, 40}
s2 = {30, 40, 50, 60}
print("Union using method:", s1.union(s2))
print("Intersection using method:", s1.intersection(s2))
print("Difference using method:", s1.difference(s2))
print("Symmetric difference using method:", s1.symmetric_difference(s2))
# Out:
# Union using method: {40, 10, 50, 20, 60, 30}
# Intersection using method: {40, 30}
# Difference using method: {10, 20}
# Symmetric difference using method: {10, 50, 20, 60}

# %%
# Creating tuples
t = (10, 20, 30, 40, 20)
print("Original tuple:", t)
# Out:
# Original tuple: (10, 20, 30, 40, 20)

# %%
# Accessing elements
t = (10, 20, 30, 40, 20)
print("First element:", t[0])
print("Last element:", t[-1])
# Out:
# First element: 10
# Last element: 20

# %%
# Slicing
t = (10, 20, 30, 40, 20)
print("Sliced tuple:", t[1:4])
# Out:
# Sliced tuple: (20, 30, 40)

# %%
# Length
t = (10, 20, 30, 40, 20)
print("Length of tuple:", len(t))
# Out:
# Length of tuple: 5

# %%
# Counting elements
t = (10, 20, 30, 40, 20)
print("Count of 20:", t.count(20))
# Out:
# Count of 20: 2

# %%
# Finding index
t = (10, 20, 30, 40, 20)
print("Index of 40:", t.index(40))
# Out:
# Index of 40: 3

# %%
#Looping
t = (10, 20, 30, 40, 20)
print("Tuple elements:")
for item in t:
    print(item)
# Out:
# Tuple elements:
# 10
# 20
# 30
# 40
# 20

# %%
# Concatenation
t = (10, 20, 30, 40, 20)
t2 = (50, 60)
t3 = t + t2
print("After concatenation:", t3)
# Out:
# After concatenation: (10, 20, 30, 40, 20, 50, 60)

# %%
# Repetition
t = (10, 20, 30, 40, 20)
t4 = t * 2
print("After repetition:", t4)
# Out:
# After repetition: (10, 20, 30, 40, 20, 10, 20, 30, 40, 20)

# %%
# Nested tuple
t = (10, 20, 30, 40, 20)
nested = (1, (2, 3), (4, 5))
print("Nested tuple element:", nested[1][0])
# Out:
# Nested tuple element: 2
