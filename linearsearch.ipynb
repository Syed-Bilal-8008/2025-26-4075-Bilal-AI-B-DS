# %% [markdown]
# <a href="https://colab.research.google.com/github/Syed-Bilal-8008/2025-26-4075-Bilal-AI-B-DS/blob/main/linearsearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number of elements: "))
arr = []

# Taking array elements from user
for i in range(n):
    value = int(input(f"Enter element {i+1}: "))
    arr.append(value)

key = int(input("Enter element to search: "))
found = False

# Linear search
for i in range(n):
    if arr[i] == key:
        print("Element found at index", i)
        found = True
        break

if not found:
    print("Element not found")
# Out:
# Enter number of elements: 4
# Enter element 1: 1
# Enter element 2: 3
# Enter element 3: 4
# Enter element 4: 5
# Enter element to search: 3
# Element found at index 1
