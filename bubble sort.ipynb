# %% [markdown]
# <a href="https://colab.research.google.com/github/Syed-Bilal-8008/2025-26-4075-Bilal-AI-B-DS/blob/main/bubble%20sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bubble sort
n = int(input("Enter number of elements: "))

arr = []

# Taking elements from user
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal array:", arr)

# Bubble sort logic
for i in range(n-1):
    for j in range(n-1-i):
        if arr[j] > arr[j+1]:
            # Swap
            arr[j], arr[j+1] = arr[j+1], arr[j]

print("Sorted array:", arr)
# Out:
# Enter number of elements: 4
# Enter element 1: 6
# Enter element 2: 3
# Enter element 3: 9
# Enter element 4: 1
#
# Original array: [6, 3, 9, 1]
# Sorted array: [1, 3, 6, 9]
